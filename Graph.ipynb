# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel("C:/Users/berky/Desktop/Zula_Grafikler/Ayrı_ayrı_yöntemler_MAPE.xlsx")

plt.figure(figsize = (40,20))

ax = plt.subplot(4,4,1)
bars = ax.bar(data.Date_Time, data.MLP_7fc_MAPE, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("06.09-12.09 7fc MLP MAPE(avg 12)")

ax = plt.subplot(4,4,2)
bars = ax.bar(data.Date_Time, data.MLP_8fc_MAPE, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("06.09-12.09 8fc MLP MAPE(avg 13)")

ax = plt.subplot(4,4,3)
bars = ax.bar(data.Date_Time, data.SVM_7fc_MAPE, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("06.09-12.09 7fc SVM MAPE(avg 11)")

ax = plt.subplot(4,4,4)
bars = ax.bar(data.Date_Time, data.SVM_8fc_MAPE, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("06.09-12.09 8fc SVM MAPE(avg 10)")

plt.savefig(fname = "06.09-12.09_Yöntemlerin_Ayrı_MAPEleri.pdf")

plt.show()

# %%
data = pd.read_excel("C:/Users/berky/Desktop/Zula_Grafikler/Ayrı_ayrı_yöntemler_MAE.xlsx")

plt.figure(figsize = (40,20))

ax = plt.subplot(4,4,1)
bars = ax.bar(data.Date_Time, data.MLP_7fc_MAE, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("06.09-12.09 7fc MLP MAE(avg 35)")

ax = plt.subplot(4,4,2)
bars = ax.bar(data.Date_Time, data.MLP_8fc_MAE, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("06.09-12.09 8fc MLP MAE(avg 40)")

ax = plt.subplot(4,4,3)
bars = ax.bar(data.Date_Time, data.SVM_7fc_MAE, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("06.09-12.09 7fc SVM MAE(avg 31)")

ax = plt.subplot(4,4,4)
bars = ax.bar(data.Date_Time, data.SVM_8fc_MAE, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("06.09-12.09 8fc SVM MAE(avg 27)")

plt.savefig(fname = "06.09-12.09_Yöntemlerin_Ayrı_MAEleri.pdf")

plt.show()

# %%
data = pd.read_excel("C:/Users/berky/Desktop/Zula_Grafikler/Yöntem_Kıyas_MAPE.xlsx")

plt.figure(figsize = (70,35))

ax = plt.subplot(7,7,1)
bars = ax.bar(data.Date_Time, data.Gün_1, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("06.09 MAPE")

ax = plt.subplot(7,7,2)
bars = ax.bar(data.Date_Time, data.Gün_2, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("07.09 MAPE")

ax = plt.subplot(7,7,3)
bars = ax.bar(data.Date_Time, data.Gün_3, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("08.09 MAPE")

ax = plt.subplot(7,7,4)
bars = ax.bar(data.Date_Time, data.Gün_4, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("09.09 MAPE")

ax = plt.subplot(7,7,5)
bars = ax.bar(data.Date_Time, data.Gün_5, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("10.09 MAPE")

ax = plt.subplot(7,7,6)
bars = ax.bar(data.Date_Time, data.Gün_6, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("11.09 MAPE")

ax = plt.subplot(7,7,7)
bars = ax.bar(data.Date_Time, data.Gün_7, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("12.09 MAPE")

plt.savefig(fname = "06.09-12.09_MAPE_Kıyas.pdf")

plt.show()

# %%
data = pd.read_excel("C:/Users/berky/Desktop/Zula_Grafikler/Yöntem_Kıyas_MAE.xlsx")

plt.figure(figsize = (70,35))

ax = plt.subplot(7,7,1)
bars = ax.bar(data.Date_Time, data.Gün_1, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("06.09 MAE")

ax = plt.subplot(7,7,2)
bars = ax.bar(data.Date_Time, data.Gün_2, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("07.09 MAE")

ax = plt.subplot(7,7,3)
bars = ax.bar(data.Date_Time, data.Gün_3, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("08.09 MAE")

ax = plt.subplot(7,7,4)
bars = ax.bar(data.Date_Time, data.Gün_4, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("09.09 MAE")

ax = plt.subplot(7,7,5)
bars = ax.bar(data.Date_Time, data.Gün_5, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("10.09 MAE")

ax = plt.subplot(7,7,6)
bars = ax.bar(data.Date_Time, data.Gün_6, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("11.09 MAE")

ax = plt.subplot(7,7,7)
bars = ax.bar(data.Date_Time, data.Gün_7, width=0.5)

for bar in bars:
  height = int(bar.get_height())
  label_x_pos = bar.get_x() + bar.get_width() / 2
  ax.text(label_x_pos, height, s=f'{height}', ha='center',
  va='bottom')

plt.title("12.09 MAE")

plt.savefig(fname = "06.09-12.09_MAE_Kıyas.pdf")

plt.show()
